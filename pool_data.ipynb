# %%
import pandas as pd

# %%
file = '/Users/HANCHU/swimming_sis/upuhupuh/fulldata_10_35_01_P.csv'

# %%
df = pd.read_csv(file, encoding='cp949')

# %%
df
# Out:
#         번호 개방서비스명    개방서비스아이디  개방자치단체코드                  관리번호       인허가일자  \
# 0        1   수영장업  10_35_01_P   4490000  CDFH3301012002000002  2002-07-04
# 1        2   수영장업  10_35_01_P   4490000  CDFH3301012015000001  2015-03-20
# 2        3   수영장업  10_35_01_P   5060000  CDFH3301012003000002  2003-02-21
# 3        4   수영장업  10_35_01_P   5050000  CDFH3301012001000001  2001-10-26
# 4        5   수영장업  10_35_01_P   5050000  CDFH3301012003000002  2003-12-20
# ...    ...    ...         ...       ...                   ...         ...
# 1659  1660   수영장업  10_35_01_P   4050000  CDFH3301012006000003  2006-12-13
# 1660  1661   수영장업  10_35_01_P   3100000  CDFH3301012004000001  2004-03-08
# 1661  1662   수영장업  10_35_01_P   3160000  CDFH3301012003000001  2003-09-01
# 1662  1663   수영장업  10_35_01_P   3220000  CDFH3301012000000001  2000-11-10
# 1663  1664   수영장업  10_35_01_P   5570000  CDFH3301012008000001  2008-07-21
#
#      인허가취소일자  영업상태구분코드           영업상태명  상세영업상태코드  ... 문화체육업종명 공사립구분명 보험가입여부코드  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1664 entries, 0 to 1663
# Data columns (total 38 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   번호           1664 non-null   int64
#  1   개방서비스명       1664 non-null   object
#  2   개방서비스아이디     1664 non-null   object
#  3   개방자치단체코드     1664 non-null   int64
#  4   관리번호         1664 non-null   object
#  5   인허가일자        1664 non-null   object
#  6   인허가취소일자      12 non-null     object
#  7   영업상태구분코드     1664 non-null   int64
#  8   영업상태명        1664 non-null   object
#  9   상세영업상태코드     1664 non-null   int64
#  10  상세영업상태명      1664 non-null   object
#  11  폐업일자         674 non-null    object
#  12  휴업시작일자       64 non-null     object
#  13  휴업종료일자       63 non-null     object
#  14  재개업일자        0 non-null      float64
#  15  소재지전화        1337 non-null   object
#  16  소재지면적        0 non-null      float64
#  17  소재지우편번호      896 non-null    object
# ...

# %%
df.isnull()
# Out:
#          번호  개방서비스명  개방서비스아이디  개방자치단체코드   관리번호  인허가일자  인허가취소일자  영업상태구분코드  \
# 0     False   False     False     False  False  False     True     False
# 1     False   False     False     False  False  False     True     False
# 2     False   False     False     False  False  False     True     False
# 3     False   False     False     False  False  False     True     False
# 4     False   False     False     False  False  False     True     False
# ...     ...     ...       ...       ...    ...    ...      ...       ...
# 1659  False   False     False     False  False  False     True     False
# 1660  False   False     False     False  False  False     True     False
# 1661  False   False     False     False  False  False     True     False
# 1662  False   False     False     False  False  False     True     False
# 1663  False   False     False     False  False  False     True     False
#
#       영업상태명  상세영업상태코드  ...  문화체육업종명  공사립구분명  보험가입여부코드   지도자수  건축물동수  건축물연면적  \
# ...

# %%
df.drop_duplicates()
# Out:
#         번호 개방서비스명    개방서비스아이디  개방자치단체코드                  관리번호       인허가일자  \
# 0        1   수영장업  10_35_01_P   4490000  CDFH3301012002000002  2002-07-04
# 1        2   수영장업  10_35_01_P   4490000  CDFH3301012015000001  2015-03-20
# 2        3   수영장업  10_35_01_P   5060000  CDFH3301012003000002  2003-02-21
# 3        4   수영장업  10_35_01_P   5050000  CDFH3301012001000001  2001-10-26
# 4        5   수영장업  10_35_01_P   5050000  CDFH3301012003000002  2003-12-20
# ...    ...    ...         ...       ...                   ...         ...
# 1659  1660   수영장업  10_35_01_P   4050000  CDFH3301012006000003  2006-12-13
# 1660  1661   수영장업  10_35_01_P   3100000  CDFH3301012004000001  2004-03-08
# 1661  1662   수영장업  10_35_01_P   3160000  CDFH3301012003000001  2003-09-01
# 1662  1663   수영장업  10_35_01_P   3220000  CDFH3301012000000001  2000-11-10
# 1663  1664   수영장업  10_35_01_P   5570000  CDFH3301012008000001  2008-07-21
#
#      인허가취소일자  영업상태구분코드           영업상태명  상세영업상태코드  ... 문화체육업종명 공사립구분명 보험가입여부코드  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1664 entries, 0 to 1663
# Data columns (total 38 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   번호           1664 non-null   int64
#  1   개방서비스명       1664 non-null   object
#  2   개방서비스아이디     1664 non-null   object
#  3   개방자치단체코드     1664 non-null   int64
#  4   관리번호         1664 non-null   object
#  5   인허가일자        1664 non-null   object
#  6   인허가취소일자      12 non-null     object
#  7   영업상태구분코드     1664 non-null   int64
#  8   영업상태명        1664 non-null   object
#  9   상세영업상태코드     1664 non-null   int64
#  10  상세영업상태명      1664 non-null   object
#  11  폐업일자         674 non-null    object
#  12  휴업시작일자       64 non-null     object
#  13  휴업종료일자       63 non-null     object
#  14  재개업일자        0 non-null      float64
#  15  소재지전화        1337 non-null   object
#  16  소재지면적        0 non-null      float64
#  17  소재지우편번호      896 non-null    object
# ...

# %%
df.head(10)
# Out:
#    번호 개방서비스명    개방서비스아이디  개방자치단체코드                  관리번호       인허가일자 인허가취소일자  \
# 0   1   수영장업  10_35_01_P   4490000  CDFH3301012002000002  2002-07-04     NaN
# 1   2   수영장업  10_35_01_P   4490000  CDFH3301012015000001  2015-03-20     NaN
# 2   3   수영장업  10_35_01_P   5060000  CDFH3301012003000002  2003-02-21     NaN
# 3   4   수영장업  10_35_01_P   5050000  CDFH3301012001000001  2001-10-26     NaN
# 4   5   수영장업  10_35_01_P   5050000  CDFH3301012003000002  2003-12-20     NaN
# 5   6   수영장업  10_35_01_P   5340000  CDFH3301012016000001  2016-06-28     NaN
# 6   7   수영장업  10_35_01_P   4910000  CDFH3301012005000001  2005-08-05     NaN
# 7   8   수영장업  10_35_01_P   4670000  CDFH3301012005000001  2005-02-19     NaN
# 8   9   수영장업  10_35_01_P   6520000  CDFH3301012015000001  2015-07-12     NaN
# 9  10   수영장업  10_35_01_P   5600000  CDFH3301011990000001  1990-01-13     NaN
#
#    영업상태구분코드 영업상태명  상세영업상태코드  ... 문화체육업종명 공사립구분명 보험가입여부코드 지도자수  건축물동수  \
# ...

# %%
df_sample = df.iloc[:,[7, 8, 15, 18, 19, 21, 26, 27, 29]]
df_sample.head(5)
# Out:
#    영업상태구분코드 영업상태명         소재지전화                     소재지전체주소  \
# 0         2    휴업  041-560-9114  충청남도 천안시 동남구 수신면 장산리 669-1
# 1         2    휴업      577-2090        충청남도 천안시 동남구 안서동 211
# 2         2    휴업      433-9475      경상북도 김천시 봉산면 태화리 483번지
# 3         2    휴업           NaN         경상북도 경주시 북군동 11-1번지
# 4         2    휴업  054-744-1199       경상북도 경주시 신평동 601-19번지
#
#                             도로명전체주소                   사업장명        좌표정보(x)  \
# 0  충청남도 천안시 동남구 수신면 수신로 576 (상록리조트)                  상록수영장  225693.408769
# 1        충청남도 천안시 동남구 성불사길 36 (안서동)              (주)홍익힐링센터  216807.307340
# 2             경상북도 김천시 봉산면 영남대로 734              둥굴관광농원수영장  292217.588046
# 3         경상북도 경주시 보문로 182-29 (북군동)  (주)이랜드파크켄싱턴리조트경주실외수영장  404841.798100
# 4            경상북도 경주시 보문로 365 (신평동)          일성경주보문콘도실내수영장  406006.834844
#
#          좌표정보(y) 공사립구분명
# 0  359978.556736     사립
# 1  369696.353430     사립
# 2  294393.746691     사립
# 3  264595.723083     사립
# 4  263329.635881     사립

# %%
df_subset = df_sample[df['영업상태명']=='영업/정상']
df_subset.head(5)
# Out:
#      영업상태구분코드  영업상태명         소재지전화              소재지전체주소  \
# 661         1  영업/정상      986-5012    대구광역시 동구 방촌동 1047
# 662         1  영업/정상  053-572-2451    대구광역시 서구 이현동 48-8
# 663         1  영업/정상  042-820-0722  대전광역시 유성구 봉명동 443-1
# 664         1  영업/정상      716-3000  대전광역시 대덕구 목상동 871번지
# 665         1  영업/정상           NaN  대전광역시 대덕구 석봉동 780번지
#
#                               도로명전체주소              사업장명        좌표정보(x)  \
# 661  대구광역시 동구 동촌로 168 (방촌동, 대구동촌초등학교)          동촌아쿠아수영장  349670.669719
# 662            대구광역시 서구 문화로 122 (이현동)          서구청소년수련관  339527.335473
# 663             대전광역시 유성구 온천로 9 (봉명동)         유성호텔실내수영장  230306.862971
# 664    대전광역시 대덕구 대덕대로1486번길 101 (목상동)       대덕국민체육센터수영장  236993.567015
# 665    대전광역시 대덕구 대덕대로1527번길 200 (석봉동)  금강로하스산호빛공원 야외수영장  237654.279171
#
#            좌표정보(y) 공사립구분명
# 661  265952.526820     사립
# 662  264811.114119     사립
# 663  317342.346429     사립
# 664  327258.245009     사립
# 665  328166.329394     사립

# %%
df_subset['홈페이지링크']= df_subset['사업장명']+'link'
# Out:
# /var/folders/_1/ryhz_nds7c71jhflnvglc22h0000gn/T/ipykernel_12462/3561261987.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset['홈페이지링크']= df_subset['사업장명']+'link'

# %%
df_subset = df_subset.drop('영업상태명',axis=1)
df_subset.head(5)
# Out:
#      영업상태구분코드         소재지전화              소재지전체주소  \
# 661         1      986-5012    대구광역시 동구 방촌동 1047
# 662         1  053-572-2451    대구광역시 서구 이현동 48-8
# 663         1  042-820-0722  대전광역시 유성구 봉명동 443-1
# 664         1      716-3000  대전광역시 대덕구 목상동 871번지
# 665         1           NaN  대전광역시 대덕구 석봉동 780번지
#
#                               도로명전체주소              사업장명        좌표정보(x)  \
# 661  대구광역시 동구 동촌로 168 (방촌동, 대구동촌초등학교)          동촌아쿠아수영장  349670.669719
# 662            대구광역시 서구 문화로 122 (이현동)          서구청소년수련관  339527.335473
# 663             대전광역시 유성구 온천로 9 (봉명동)         유성호텔실내수영장  230306.862971
# 664    대전광역시 대덕구 대덕대로1486번길 101 (목상동)       대덕국민체육센터수영장  236993.567015
# 665    대전광역시 대덕구 대덕대로1527번길 200 (석봉동)  금강로하스산호빛공원 야외수영장  237654.279171
#
#            좌표정보(y) 공사립구분명                홈페이지링크
# 661  265952.526820     사립          동촌아쿠아수영장link
# 662  264811.114119     사립          서구청소년수련관link
# 663  317342.346429     사립         유성호텔실내수영장link
# ...

# %%
df_subset = df_subset.drop('공사립구분명',axis=1)
df_subset.head(5)
# Out:
#      영업상태구분코드         소재지전화              소재지전체주소  \
# 661         1      986-5012    대구광역시 동구 방촌동 1047
# 662         1  053-572-2451    대구광역시 서구 이현동 48-8
# 663         1  042-820-0722  대전광역시 유성구 봉명동 443-1
# 664         1      716-3000  대전광역시 대덕구 목상동 871번지
# 665         1           NaN  대전광역시 대덕구 석봉동 780번지
#
#                               도로명전체주소              사업장명        좌표정보(x)  \
# 661  대구광역시 동구 동촌로 168 (방촌동, 대구동촌초등학교)          동촌아쿠아수영장  349670.669719
# 662            대구광역시 서구 문화로 122 (이현동)          서구청소년수련관  339527.335473
# 663             대전광역시 유성구 온천로 9 (봉명동)         유성호텔실내수영장  230306.862971
# 664    대전광역시 대덕구 대덕대로1486번길 101 (목상동)       대덕국민체육센터수영장  236993.567015
# 665    대전광역시 대덕구 대덕대로1527번길 200 (석봉동)  금강로하스산호빛공원 야외수영장  237654.279171
#
#            좌표정보(y)                홈페이지링크
# 661  265952.526820          동촌아쿠아수영장link
# 662  264811.114119          서구청소년수련관link
# 663  317342.346429         유성호텔실내수영장link
# 664  327258.245009       대덕국민체육센터수영장link
# ...

# %%
idx = df_subset[~df_subset['사업장명'].str.contains('호텔')]

# %%
idx = idx[~idx['사업장명'].str.contains('리조트')]

# %%
idx = idx[~idx['사업장명'].str.contains('차일드')]

# %%
idx = idx[~idx['사업장명'].str.contains('키즈')]

# %%
idx = idx[~idx['사업장명'].str.contains('어린이')]

# %%
idx = idx[~idx['사업장명'].str.contains('야외')]

# %%
idx = idx[~idx['사업장명'].str.contains('실외')]

# %%
idx = idx[~idx['사업장명'].str.contains('옥외')]

# %%
idx = idx[~idx['사업장명'].str.contains('콘도')]

# %%
idx = idx[~idx['사업장명'].str.contains('인피니티')]

# %%
idx = idx[~idx['사업장명'].str.contains('워터파크')]

# %%
idx = idx[~idx['사업장명'].str.contains('스파')]

# %%
idx.sort_values(by=['도로명전체주소'], inplace=True)

# %%
idx.reset_index(drop=True)
# Out:
#      영업상태구분코드         소재지전화                        소재지전체주소  \
# 0           1  033-651-4551   강원특별자치도 강릉시 포남동 산 90-1 강릉아레나
# 1           1  033-640-4550           강원특별자치도 강릉시 교동 458-1
# 2           1  033-662-0972    강원특별자치도 강릉시 주문진읍 교항리 48-160
# 3           1  033-655-6565          강원특별자치도 강릉시 박월동 448-1
# 4           1  033-820-7325  강원특별자치도 강릉시 안현동 89-87 라카이샌드파인
# ..        ...           ...                            ...
# 580         1           NaN             서울특별시 중구 순화동 2-6번지
# 581         1           NaN            서울특별시 중구 흥인동 13-1번지
# 582         1      739-0283             서울특별시 중구 정동 1-76번지
# 583         1  064-793-9007      제주특별자치도 서귀포시 안덕면 광평리 25-1
# 584         1      903-7111    서울특별시 도봉구 창동 804번지 대우@상가 3층
#
#                                 도로명전체주소               사업장명        좌표정보(x)  \
# 0     강원특별자치도 강릉시 수리골길 102, 강릉아레나 (포남동)            아레나 수영장            NaN
# 1              강원특별자치도 강릉시 수리골길 76 (교동)           강릉국민체육센터  367074.905017
# ...

# %%
idx.head(5)
# Out:
#       영업상태구분코드         소재지전화                        소재지전체주소  \
# 1000         1  033-651-4551   강원특별자치도 강릉시 포남동 산 90-1 강릉아레나
# 991          1  033-640-4550           강원특별자치도 강릉시 교동 458-1
# 999          1  033-662-0972    강원특별자치도 강릉시 주문진읍 교항리 48-160
# 990          1  033-655-6565          강원특별자치도 강릉시 박월동 448-1
# 805          1  033-820-7325  강원특별자치도 강릉시 안현동 89-87 라카이샌드파인
#
#                                  도로명전체주소          사업장명        좌표정보(x)  \
# 1000   강원특별자치도 강릉시 수리골길 102, 강릉아레나 (포남동)       아레나 수영장            NaN
# 991             강원특별자치도 강릉시 수리골길 76 (교동)      강릉국민체육센터  367074.905017
# 999             강원특별자치도 강릉시 주문진읍 연주로 272        북부 수영장  361194.329232
# 990            강원특별자치도 강릉시 칠성로 491 (박월동)         강릉수영장  368617.649543
# 805   강원특별자치도 강릉시 해안로 536, 라카이샌드파인 (안현동)  더 라니 풀 ＆ 사우나  367621.813149
#
#             좌표정보(y)            홈페이지링크
# 1000            NaN       아레나 수영장link
# 991   476610.965475      강릉국민체육센터link
# 999   487596.286623        북부 수영장link
# ...

# %%
idx.to_excel(
    excel_writer = '/Users/HANCHU/swimming_sis/upuhupuh/pooldata_idx_swimming.xlsx',
    sheet_name = '수영장업 정보'
)
